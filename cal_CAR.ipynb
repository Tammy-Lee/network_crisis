# %%
# 引入包
import time

import statsmodels.api as sm 
import pandas as pd
import numpy as np

from datetime import datetime, timedelta
from functools import wraps

# %%
# 显示一个函数的运行时间
def show_running_time(func):
    @wraps(func)
    def _show_time(*args, **kwargs):
        now = datetime.now()
        result = func(*args, **kwargs)
        print(func.__name__, datetime.now() - now)
        return result
    return _show_time

# %%
# 构造通用股票code
def get_commoncode(str1):
    
    str2=str1
    if str1[0]=='0':
        str2=str1+'.SZ'
    elif str1[0]=='6':
        str2=str1+'.SH'
        
    return str2

# %%
# 获得股票数据窗口数据
# @show_running_time
def get_window_data(all_stock_data_new, stock_code, event_date, hs300, date_range=(-128,-8), index_column="Indexcd", code_column="Stkcd", date_column="Trddt", real_return_column="Dretwd",index_return_column="Retindex"):
    # 构造window data，hs300_return指大盘回报，stock_return指相同期间内的回报。
    
    # 筛选出对应股票代码的股票日交易数据
#     t1 = datetime.now()
#     stock_data = all_stock_data[all_stock_data[code_column] == stock_code]
    stock_data = all_stock_data_new[stock_code]
#     t2 = datetime.now()
#     print("first:", t2 - t1)
    count = 0
    while event_date not in list(stock_data[date_column]) and count <= 7:
        event_date = event_date + timedelta(days=1)  
        count += 1
    
#     print("second:", datetime.now() - t2)
    StockDateIndex = stock_data[stock_data[date_column] == event_date].index[0]

    stock_data = stock_data.loc[(StockDateIndex+date_range[0]):(StockDateIndex+date_range[1]),:]
#     print(stock_data.shape)
    
    StockDateList = stock_data[date_column]
    if stock_code.endswith(".SH"):
        hs300_return = hs300[(hs300[date_column].isin(StockDateList)) & (hs300[index_column]==1)][index_return_column]
    else:
        hs300_return = hs300[(hs300[date_column].isin(StockDateList)) & (hs300[index_column]==399106)][index_return_column]
    stock_return = stock_data[real_return_column]

#     print(len(hs300_return), len(stock_return))
    return hs300_return, stock_return

# %%
# 计算alpha和beta
# @show_running_time
def pre_alpha_beta(all_stock_data, stock_code, event_date, hs300):
    # stock_return = alpha + beta*hs300_return
    hs300_return, stock_return = get_window_data(all_stock_data, stock_code, event_date, hs300)
    x = sm.add_constant(list(hs300_return))
    #线性回归增加常数项 y=kx+b
    y = list(stock_return)
    regr = sm.OLS(y,x)
    res = regr.fit() 
    alpha = res.params[0]
    beta = res.params[1]
    
    return alpha, beta

# %%
# 计算超额收益率
# @show_running_time
def cal_single_CAR(all_stock_data, stock_code, event_date, hs300):
    
    Alpha, Beta = pre_alpha_beta(all_stock_data, stock_code, event_date, hs300)
    
    calWindowHs300Ret_Data, calWindowStockRet_Data = get_window_data(all_stock_data, stock_code, event_date, date_range=[-1, 1], hs300=hs300)
    
    fitvalue_y = Alpha + Beta*np.array(calWindowHs300Ret_Data)
    AR_array = calWindowStockRet_Data - fitvalue_y
    single_car = AR_array.sum()

    return single_car

# %%
# @show_running_time
def get_crisis_data(path):
    crisis_data = pd.read_excel(path, parse_dates=["披露日期"])
    print("crisis_data is loading successfully")
    print(crisis_data.shape)
    print(crisis_data.head())
    print("============done!=============")
    return crisis_data

# %%
# get_crisis_data(r"选择危机事件并划分种类.xlsx")

# %%
@show_running_time
def get_index_data(path):
    index_return = pd.read_table(path, parse_dates=["Trddt"], encoding="gbk")
    print("index_data_all is loading successfully")
    print(index_return.shape)
    print(index_return.head())
    print(index_return.dtypes)
    print("============done!=============")
    return index_return

# %%
@show_running_time
def get_all_stock_data(path):
    stock = pd.read_table(path,dtype={"Stkcd":str}, encoding="gbk", skiprows=[1,2],  parse_dates=["Trddt"])
    stock['Stkcd']=stock['Stkcd'].apply(get_commoncode)
    print("stock_data is loading successfully")
    print(stock.shape)
    print(stock.head())
    print("============done!=============")
    return stock

# %%
# 计算CAR
@show_running_time
def cal_all_CAR(paths, all_stock_data, hs300, crisis_data):
    
    for i in crisis_data.index:
        stock_code = crisis_data.loc[i, "证券代码"]
#         print(stock_code)
        event_date = crisis_data.loc[i, "披露日期"]
        try:
            single_car = cal_single_CAR(all_stock_data, stock_code, event_date, hs300=hs300)
#             print(single_car)
            crisis_data.loc[i, "CAR"] = single_car
        except:
            continue

    return crisis_data

# %%
if __name__ == "__main__":
    paths = {"crisis_data": r"选择危机事件并划分种类.xlsx", 
            "index_return": r"TRD_Index.txt",
            "stock_data": r"TRD_Dalyr.txt"}
    
    crisis_data = get_crisis_data(paths["crisis_data"])    
    hs300 = get_index_data(paths["index_return"])
    all_stock_data = get_all_stock_data(paths["stock_data"])
# Out:
# crisis_data is loading successfully
# (796, 10)
#           证券代码   证券名称 证券类型  事件大类    事件类型      发生日期  事件类型编码 事件梗概  \
# 312  600397.SH  *ST安煤   股票  经营事件      停产  20161124     NaN  NaN
# 14   600408.SH  *ST安泰   股票  红色预警  违规行为公告  20150724     5.0  NaN
# 167  600408.SH  *ST安泰   股票  红色预警  违规行为公告  20160421     5.0  NaN
# 631  600408.SH  *ST安泰   股票  红色预警  违规行为公告  20171214     5.0  NaN
# 738  002188.SZ  *ST巴士   股票  红色预警  立案调查开始  20180426     NaN  NaN
#
#                                                   事件摘要       披露日期
# 312  根据《江西省化解过剩产能领导小组办公室关于做好调整2016年度煤矿关闭退出计划的紧急通知》要... 2016-11-25
# 14   因未及时披露公司重大事项,未依法履行其他职责，上海证券交易所于2015-07-24依据相关法... 2015-07-24
# 167  因未及时披露公司重大事项，中国证券监督管理委员会于2016-04-20依据相关法规给予:公开... 2016-04-21
# 631  因未及时披露公司重大事项,未依法履行其他职责，上海证券交易所于2017-12-13依据相关法... 2017-12-14
# 738  中国证券监督管理委员会对公司巴士在线股份有限公司(以下简称 “公司” )于 2018 年 4... 2018-04-27
# ============done!=============
# index_data_all is loading successfully
# (24989, 8)
#    Indexcd      Trddt  Daywk  Opnindex   Hiindex   Loindex  Clsindex  Retindex
# 0        1 2011-08-29      1  2595.466  2595.466  2570.844  2576.413 -0.013695
# 1        1 2011-08-30      2  2592.597  2615.135  2563.689  2566.595 -0.003811
# 2        1 2011-08-31      3  2566.529  2574.415  2545.096  2567.340  0.000290
# 3        1 2011-09-01      4  2569.799  2584.804  2547.855  2556.042 -0.004401
# 4        1 2011-09-02      5  2551.556  2557.310  2517.618  2528.280 -0.010861
# Indexcd              int64
# Trddt       datetime64[ns]
# Daywk                int64
# Opnindex           float64
# Hiindex            float64
# Loindex            float64
# Clsindex           float64
# Retindex           float64
# dtype: object
# ============done!=============
# get_index_data 0:00:00.078253
# stock_data is loading successfully
# (9538993, 17)
#        Stkcd      Trddt  Opnprc  Hiprc  Loprc  Clsprc   Dnshrtrd  \
# 0  000001.SZ 2018-08-24    9.31  10.28   9.29   10.03  304040839
# 1  000001.SZ 2018-08-23    9.30   9.42   9.23    9.36   72907462
# 2  000001.SZ 2018-08-22    9.24   9.34   9.13    9.29   98243398
# 3  000001.SZ 2018-08-21    9.02   9.26   9.01    9.23  126447447
# 4  000001.SZ 2018-08-20    8.90   9.02   8.87    9.00   68132206
#
#        Dnvaltrd       Dsmvosd       Dsmvtll    Dretwd    Dretnd     Adjprcwd  \
# 0  2.995072e+09  1.722176e+08  1.722192e+08  0.071581  0.071581  1040.616269
# 1  6.809414e+08  1.607135e+08  1.607151e+08  0.007535  0.007535   971.103517
# 2  9.095987e+08  1.595116e+08  1.595131e+08  0.006501  0.006501   963.840991
# 3  1.163293e+09  1.584814e+08  1.584829e+08  0.025556  0.025556   957.615968
# 4  6.099347e+08  1.545322e+08  1.545337e+08  0.021566  0.021566   933.753382
#
#      Adjprcnd  Markettype    Capchgdt  Trdsta
# 0  830.846559           4  2018-05-21       1
# 1  775.346340           4  2018-05-21       1
# 2  769.547810           4  2018-05-21       1
# 3  764.577641           4  2018-05-21       1
# 4  745.525327           4  2018-05-21       1
# ============done!=============
# get_all_stock_data 0:00:43.869392

# %%
gen = all_stock_data.groupby("Stkcd")
all_stock_data_new = {key:value for key, value in gen}

# %%
crisis_data_CAR = cal_all_CAR(paths, all_stock_data_new, hs300, crisis_data)
# Out:
# cal_all_CAR 0:00:47.501320

# %%
crisis_data_CAR.to_csv("crisis_data_CAR.csv", index=None,encoding="gbk")

# %%
from multiprocessing import Pool
from multiprocessing.dummy import Pool as TheadPool

# %%
indexes = list(crisis_data.index)
crisis_data["CAR"] = 0

# %%
def deal_one_record(i):
    stock_code = crisis_data.loc[i, "证券代码"]
    print(stock_code)
    event_date = crisis_data.loc[i, "披露日期"]
    try:
        single_car = cal_single_CAR(all_stock_data, stock_code, event_date, hs300=hs300)
        print(single_car)
        crisis_data.loc[i, "CAR"] = single_car
    except:
        crisis_data.loc[i, "CAR"] = np.nan
    print("===========")

# %%
pool = TheadPool(4)
results = pool.map(deal_one_record, indexes)
pool.close()
pool.join()
# Out:
# 600397.SH000922.SZ
# 002306.SZ
#
# 600696.SH
# 0.01119751199569818
# ===========
# 600321.SH
# 0.006181292911197893
# -0.1419235915325367
# ======================
# 600696.SH
#
# 600408.SH
# -0.07999082044017909
# ===========
# 000922.SZ
# -0.06794069962646423
# ===========
# 600696.SH
# 0.31884510180208797
# ===========
# 600321.SH
# 0.00563286953163651
# ===========
# 000922.SZ
# 0.015566677774518168
# ===========
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-627f8535553e> in <module>()
#       1 pool = TheadPool(4)
# ----> 2 results = pool.map(deal_one_record, indexes)
#       3 pool.close()
#       4 pool.join()
#
# ~/anaconda2/envs/tensorflow/lib/python3.5/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda2/envs/tensorflow/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/anaconda2/envs/tensorflow/lib/python3.5/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/anaconda2/envs/tensorflow/lib/python3.5/threading.py in wait(self, timeout)
#     547             signaled = self._flag
#     548             if not signaled:
# --> 549                 signaled = self._cond.wait(timeout)
#     550             return signaled
#     551
#
# ~/anaconda2/envs/tensorflow/lib/python3.5/threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:

# %% [markdown]
# # 协程尝试1

# %%
# import asyncio

# %%
# # 计算CAR
# async def cal_all_CAR(paths, all_stock_data, hs300, crisis_data):
    
#     for i in crisis_data.index:
#         stock_code = crisis_data.loc[i, "证券代码"]
#         print(stock_code)
#         event_date = crisis_data.loc[i, "披露日期"]
#         try:
#             single_car = cal_single_CAR(all_stock_data, stock_code, event_date, hs300=hs300)
#             print(single_car)
#             crisis_data.loc[i, "CAR"] = single_car
#         except:
#             continue

#     return crisis_data

# %%
# loop = asyncio.get_event_loop()  # 获取一个event_loop
# tasks = [cal_all_CAR(paths, all_stock_data, hs300, crisis_data)]
# loop.run_until_complete(asyncio.gather(*tasks))  # "阻塞"直到所有的tasks完成
# loop.close()

# %% [markdown]
# # 尝试2

# %%
from concurrent import futures

# %%
@show_running_time
def deal_many(indexes: list):
    with futures.ProcessPoolExecutor(3) as e:
        r = e.map(deal_one_record, indexes)
    return r

# %%
indexes = list(crisis_data.index)
crisis_data["CAR"] = 0

# %%
def deal_one_record(i):
    stock_code = crisis_data.loc[i, "证券代码"]
    print(stock_code)
    event_date = crisis_data.loc[i, "披露日期"]
    try:
        single_car = cal_single_CAR(all_stock_data, stock_code, event_date, hs300=hs300)
        print(single_car)
        crisis_data.loc[i, "CAR"] = single_car
    except:
        crisis_data.loc[i, "CAR"] = np.nan
    print("===========")

# %%
deal_many(indexes)
# Out:
# 600397.SH
# 600408.SH
# 600408.SH
# 002188.SZ
# 600408.SH
# 0.006181292911197893
# 0.01859353774454873
# ===========
# ===========
# 600074.SH
# 600074.SH
# -0.1365178103027374
# ===========
# 600074.SH
# -0.004843333544065978
# ===========
# 600074.SH
# -0.10486500512259003
# ===========
# 600074.SH
# -0.16609162447669895
# ===========
# 600074.SH
# -0.10816905544141885
# ===========
# 600074.SH
# -0.16609162447669895
# ===========
# 600074.SH
# -0.034434284414482326
# ===========
# 600247.SH
# -0.043873433311872656
# ===========
# 600247.SH
# 0.0030200894273613756
# ===========
# 600247.SH
# 0.016124021212840317
# ===========
# 600247.SH
# -0.08865299856373787
# ===========
# 600247.SH
# ===========
# 600247.SH
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/v_liliting/anaconda2/envs/tensorflow/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-16-59a647dc0e41>", line 1, in <module>
#     deal_many(indexes)
#   File "<ipython-input-2-d60248846b38>", line 6, in _show_time
#     result = func(*args, **kwargs)
#   File "<ipython-input-13-93948d99c5eb>", line 4, in deal_many
#     r = e.map(deal_one_record, indexes)
#   File "/Users/v_liliting/anaconda2/envs/tensorflow/lib/python3.5/concurrent/futures/_base.py", line 581, in __exit__
#     self.shutdown(wait=True)
#   File "/Users/v_liliting/anaconda2/envs/tensorflow/lib/python3.5/concurrent/futures/process.py", line 494, in shutdown
#     self._queue_management_thread.join()
#   File "/Users/v_liliting/anaconda2/envs/tensorflow/lib/python3.5/threading.py", line 1054, in join
#     self._wait_for_tstate_lock()
#   File "/Users/v_liliting/anaconda2/envs/tensorflow/lib/python3.5/threading.py", line 1070, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/v_liliting/anaconda2/envs/tensorflow/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 1863, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/v_liliting/anaconda2/envs/tensorflow/lib/python3.5/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/v_liliting/anaconda2/envs/tensorflow/lib/python3.5/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/v_liliting/anaconda2/envs/tensorflow/lib/python3.5/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/v_liliting/anaconda2/envs/tensorflow/lib/python3.5/inspect.py", line 1459, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/v_liliting/anaconda2/envs/tensorflow/lib/python3.5/inspect.py", line 1417, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/v_liliting/anaconda2/envs/tensorflow/lib/python3.5/inspect.py", line 677, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/v_liliting/anaconda2/envs/tensorflow/lib/python3.5/inspect.py", line 720, in getmodule
#     f = getabsfile(module)
#   File "/Users/v_liliting/anaconda2/envs/tensorflow/lib/python3.5/inspect.py", line 689, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/Users/v_liliting/anaconda2/envs/tensorflow/lib/python3.5/inspect.py", line 674, in getsourcefile
#     if os.path.exists(filename):
#   File "/Users/v_liliting/anaconda2/envs/tensorflow/lib/python3.5/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# ===========
# 600193.SH
# ===========
# 000409.SZ
# ===========
# 000585.SZ
# ===========
# 002263.SZ
# ===========
# 002194.SZ
# 0.010095166317278914
# ===========
# 002194.SZ
# -0.030842441188529773
# ===========
# 002194.SZ
# ===========
# 002194.SZ
# ===========
# 000629.SZ
# ===========
# 600399.SH
# ===========
# 600399.SH
# ===========
# 600634.SH
# ===========
# 600701.SH
# ===========
# 600401.SH
# 0.1253664372899349
# ===========
# 600401.SH
# -0.042725949816629305
# ===========
# 600401.SH
# 0.021884466597592068
# ===========
# 600401.SH
# -0.10751711998923533
# ===========
# 002018.SZ
# -0.21719758083285967
# ===========
# 000693.SZ
# -0.0340187687893971
# ===========
# 000693.SZ
# -0.04855476128779494
# ===========
# 000693.SZ
# -0.04855476128779494
# ===========
# 000693.SZ
# ===========
# ===========
# 000693.SZ
# 000693.SZ
# ===========
# ===========
# 000693.SZ
# 000693.SZ
# ===========
# 000693.SZ
# -0.04855476128779494
# ===========
# 000995.SZ
# -0.09487843111836321
# ===========
# 000995.SZ
# -0.04855476128779494
# ===========
# 000995.SZ
# -0.05720513190903347
# ===========
# 000995.SZ
# 002207.SZ
# 0.2511354111179068
# ===========
# 002207.SZ
# 0.01444740180092843
# ===========
# 002207.SZ
# 0.03588237347226551
# ===========
# 002207.SZ
# -0.028112047014712985
# ===========
# 300028.SZ
# ===========
# 300028.SZ
# ===========
# 300028.SZ
# ===========
# 300076.SZ
# ===========
# 600733.SH
# -0.03963802003850584
# ===========
# 600733.SH
# 0.08644217231516672
# ===========
# 600733.SH
# 0.08687532599829575
# ===========
# 600275.SH
# 0.02080300076857464
# ===========
# 600275.SH
# -0.040434795741429344
# ===========
# 600275.SH
# 0.049209760336982204
# ===========
# 600747.SH
# 0.0034981053385340563
# ===========
# 600747.SH
# -0.1657020512613015
# ===========
# 600747.SH
# -0.02853939555447059
# ===========
# 600747.SH
# 0.008334548776673308
# ===========
# 600817.SH
# 0.09199945129019776
# ===========
# 600817.SH
# -0.0067652889030865165
# 600608.SH
# ===========
# 0.08464005845243538
# ===========
# 600556.SH
# -0.08106714628811743
# ===========
# 600556.SH

# %%
crisis_data.head()
# Out:
#           证券代码   证券名称 证券类型  事件大类    事件类型      发生日期  事件类型编码 事件梗概  \
# 312  600397.SH  *ST安煤   股票  经营事件      停产  20161124     NaN  NaN
# 14   600408.SH  *ST安泰   股票  红色预警  违规行为公告  20150724     5.0  NaN
# 167  600408.SH  *ST安泰   股票  红色预警  违规行为公告  20160421     5.0  NaN
# 631  600408.SH  *ST安泰   股票  红色预警  违规行为公告  20171214     5.0  NaN
# 738  002188.SZ  *ST巴士   股票  红色预警  立案调查开始  20180426     NaN  NaN
#
#                                                   事件摘要       披露日期  CAR
# 312  根据《江西省化解过剩产能领导小组办公室关于做好调整2016年度煤矿关闭退出计划的紧急通知》要... 2016-11-25    0
# 14   因未及时披露公司重大事项,未依法履行其他职责，上海证券交易所于2015-07-24依据相关法... 2015-07-24    0
# 167  因未及时披露公司重大事项，中国证券监督管理委员会于2016-04-20依据相关法规给予:公开... 2016-04-21    0
# 631  因未及时披露公司重大事项,未依法履行其他职责，上海证券交易所于2017-12-13依据相关法... 2017-12-14    0
# 738  中国证券监督管理委员会对公司巴士在线股份有限公司(以下简称 “公司” )于 2018 年 4... 2018-04-27    0

# %% [markdown]
# # 尝试3

# %%
import asyncio
import math

# %%
from concurrent.futures import ThreadPoolExecutor

# %%
indexes = list(crisis_data.index)
crisis_data["CAR"] = 0

# %%
# start = time.time()
# executor = ThreadPoolExecutor(5)

# async def deal_one_record(i):
#     stock_code = crisis_data.loc[i, "证券代码"]
#     print(stock_code)
#     event_date = crisis_data.loc[i, "披露日期"]
#     try:
#         single_car = cal_single_CAR(all_stock_data, stock_code, event_date, hs300=hs300)
#         print(single_car)
#         crisis_data.loc[i, "CAR"] = single_car
#     except:
#         crisis_data.loc[i, "CAR"] = np.nan
#     print("===========")
    
# def sub_loop(indexes):
#     loop = asyncio.new_event_loop()
#     asyncio.set_event_loop(loop)
#     tasks = [deal_one_record(i) for i in indexes]
#     results = loop.run_until_complete(asyncio.gather(*tasks))
    
# async def run(executor, indexes):
#     await asyncio.get_event_loop().run_in_executor(executor, sub_loop, indexes)
    
# def chunks(l, size):
#     n = math.ceil(len(l) / size)
#     for i in range(0, len(l), n):
#         yield l[i:i + n]
        
# event_loop = asyncio.get_event_loop()
# tasks = [run(executor, chunked) for chunked in chunks(indexes, 5)]
# results = event_loop.run_until_complete(asyncio.gather(*tasks))

# print('Use asyncio+aiohttp+ThreadPoolExecutor cost: {}'.format(time.time() - start))

# %%
import time
# Out:
# -0.016312656499290902
# ===========
# 002069.SZ
# -0.01906576368580183
# ===========
# 600868.SH
# ===========
# 002715.SZ
# 0.0013226073579301906
# ===========
# 002069.SZ
# -0.039049187940703584
# ===========
# 300208.SZ
# -0.05777584194264103
# ===========
# 300330.SZ
# -0.21969084287386084
# ===========
# 002069.SZ
# -0.21969084287386084
# ===========
# 000767.SZ

# %%
2+3
# Out:
# -0.03097013873227865
# ===========
# 000767.SZ
# 5
# -0.03097013873227865
# ===========
# 000753.SZ
# -0.007173416598910605
# ===========
# 601633.SH

# %%
3+2
# Out:
# -0.0020548934526963686
# ===========
# 300208.SZ
# ===========
# 5
# 000782.SZ
# -0.02243182051780964
# ===========
# 300330.SZ

# %%
crisis_data[crisis_data.S]
# Out:
# -0.00755057578062416
# ===========
# 600757.SH
#           证券代码   证券名称 证券类型  事件大类    事件类型      发生日期  事件类型编码 事件梗概  \
# 312  600397.SH  *ST安煤   股票  经营事件      停产  20161124     NaN  NaN
# 14   600408.SH  *ST安泰   股票  红色预警  违规行为公告  20150724     5.0  NaN
# 167  600408.SH  *ST安泰   股票  红色预警  违规行为公告  20160421     5.0  NaN
# 631  600408.SH  *ST安泰   股票  红色预警  违规行为公告  20171214     5.0  NaN
# 738  002188.SZ  *ST巴士   股票  红色预警  立案调查开始  20180426     NaN  NaN
# 344  600074.SH  *ST保千   股票  红色预警  立案调查开始  20161227     NaN  NaN
# 513  600074.SH  *ST保千   股票  红色预警  违规行为公告  20170812     NaN  NaN
# 625  600074.SH  *ST保千   股票  红色预警  立案调查开始  20171211     NaN  NaN
# 639  600074.SH  *ST保千   股票  红色预警  立案调查开始  20171219     NaN  NaN
# 660  600074.SH  *ST保千   股票  红色预警  违规行为公告  20180104     NaN  NaN
# 766  600074.SH  *ST保千   股票  红色预警  立案调查开始  20180510     NaN  NaN
# 773  600074.SH  *ST保千   股票  红色预警  立案调查开始  20180515     NaN  NaN
# 775  600074.SH  *ST保千   股票  红色预警  违规行为公告  20180516     NaN  NaN
# 61   600247.SH  *ST成城   股票  红色预警  违规行为公告  20151013     NaN  NaN
# 237  600247.SH  *ST成城   股票  红色预警  违规行为公告  20160902     NaN  NaN
# 238  600247.SH  *ST成城   股票  红色预警    行政处罚  20160902     NaN  NaN
# 244  600247.SH  *ST成城   股票  红色预警  违规行为公告  20160912     NaN  NaN
# 391  600247.SH  *ST成城   股票  红色预警  违规行为公告  20170320     NaN  NaN
# 395  600247.SH  *ST成城   股票  红色预警    行政处罚  20170329     NaN  NaN
# 370  因未及时披露公司重大事项,未依法履行其他职责，上海证券交易所于2017-02-06依据相关法... 2017-02-07  0.0
# 656     因未依法履行其他职责，上海证券交易所于2017-12-28依据相关法规给予:公开谴责处分决定 2017-12-28  0.0
# 692  因未及时披露公司重大事项,信息披露虚假或严重误导性陈述，中国证券监督管理委员会上海监管局于2... 2018-02-07  0.0
# 714                  中国证券监督管理委员会对公司涉嫌信息披露违法违规行为的立案调查开始 2018-03-22  0.0
# 726  因信息披露虚假或严重误导性陈述,未依法履行其他职责，中国证券监督管理委员会上海监管局于201... 2018-04-13  0.0
# 765                  中国证券监督管理委员会对公司涉嫌信息披露违法违规行为的立案调查开始 2018-05-10  0.0
# 253  因未及时披露公司重大事项,未依法履行其他职责，中国证券监督管理委员会于2016-09-22依... 2016-09-22  0.0
# 615  中国证券监督管理委员会对公司在担任天津丰利创新投资有限公司收购徐州杰能科技发展有限公司股权事... 2017-12-02  0.0
# 533  因未及时披露公司重大事项,未依法履行其他职责，中国证券监督管理委员会湖北证监局于2017-0... 2017-08-31  0.0
# 128   因未及时披露公司重大事项，上海证券交易所于2013-11-07依据相关法规给予:公开批评处分决定 2016-01-21  0.0
# 298  因业绩预测结果不准确或不及时,未及时披露公司重大事项,未依法履行其他职责，上海证券交易所于2... 2016-11-15  0.0
# 654  因未依法履行其他职责，中国证券监督管理委员会重庆监管局于2017-12-26依据相关法规给予... 2017-12-28  0.0
# 40    因未及时披露公司重大事项，深圳证券交易所于2015-09-07依据相关法规给予:公开谴责处分决定 2015-09-07  0.0
# 429                  中国证券监督管理委员会对公司涉嫌违反证券法律法规行为的立案调查开始 2017-05-09  0.0
# 236  永利化工和株冶集团仅一墙之隔，双方长期以来履行着1995年5月18日双方所签的《株冶株化关于... 2016-09-01  0.0
#
# [796 rows x 11 columns]
# 0.012843610015316788
# ===========
# 600175.SH
# ===========
# 002715.SZ
# 0.01028063922907065
# ===========
# 600368.SH
# 0.015469441843830194
# ===========
# 000783.SZ
# 0.013755131610527667
# ===========
# 601688.SH
# 0.0042569924628792265
# ===========
# 300081.SZ
# 0.0021295152795495183
# ===========
# 000007.SZ
# 0.18344121490474927
# ===========
# 600036.SH
# -0.012413635303191006
# ===========
# 000723.SZ
# -0.027338792014603288
# ===========
# 600036.SH
# 0.01630007747102534
# ===========
# 601688.SH
# -0.027338792014603288
# ===========
# 600120.SH
# -0.04155120240077329
# ===========
# 000010.SZ
# 0.0298774879986345
# ===========
# 601688.SH
# -0.009070172442033852
# ===========
# 600070.SH
# 0.0012345407177932729
# ===========
# 000010.SZ
# -0.01701252240721594
# ===========
# 002061.SZ
# -0.01819118428088993
# ===========
# 000687.SZ
# 0.050108518029192015
# ===========
# 603991.SH
# 0.0053293321079739536
# ===========
# 600869.SH
# -0.0234162085432852
# ===========
# 000010.SZ
# ===========
# 300167.SZ
# 0.00012143550261103572
# ===========
# 000519.SZ
# -0.04685756992511206
# ===========
# 600290.SH
# -0.11020244830537154
# ===========
# 600970.SH
# 0.026689599191498957
# ===========
# 000010.SZ
# 0.00323013567024431
# ===========
# 600482.SH
# -0.03996318135398633
# ===========
# 600290.SH
# -0.016727314065676017
# ===========
# 600730.SH
# 0.07293339674287432
# ===========
# 000010.SZ
# -0.07822602355777239
# ===========
# 600730.SH
# -0.03996318135398633
# ===========
# 300071.SZ
# 0.025451540014837862
# ===========
# 600730.SH
# 0.03301564881882911
# ===========
# ===========
# 002167.SZ
# 600764.SH
# -0.02201807435123094
# ===========
# 601628.SH
# -0.07568513253444911
# ===========
# 002167.SZ
# 0.003960525025334562
# ===========
# 600086.SH
# -0.005691545578553335
# ===========
# 601628.SH
# -0.0009093280497800955
# ===========
# 000797.SZ
# 0.06459952484244195
# ===========
# 000797.SZ
# -0.10073330128521817===========
#
# 002044.SZ
# ===========
# 601618.SH
# -0.030241469036265338
# ===========
# 300027.SZ
# -0.03765199179498857
# ===========
# 000951.SZ

# %%
2
# Out:
# -0.21940437636070273
# ===========
# 002496.SZ
# 2
# -0.14981495114717358
# ===========
# 002647.SZ
# ===========
# 000020.SZ
# 0.0008640813001315785
# ===========
# 600139.SH
# ===========
# 300062.SZ
# 0.16227539313811526
# ===========
# 002496.SZ
# 0.017694665394660976
# ===========
# 002647.SZ
# 0.03678871279465824
# ===========
# 600983.SH
# 0.008416898599166374
# ===========
# 002745.SZ
# 0.1546050407712785
# ===========
# 603030.SH
# -0.013118014650883893
# ===========
# 600983.SH
# ===========
# 601166.SH
# -0.031800507585836885
# ===========
# 002278.SZ
# 0.021583263153466176
# ===========
# 000012.SZ
# -0.005093180114630769
# ===========
# 300052.SZ
# 0.02111618901465017
# ===========
# 000692.SZ
# 0.14588783194559324
# ===========
# 600139.SH
# 0.05637354913366441
# ===========
# 000504.SZ
# -0.041679330181253166
# ===========
# 000007.SZ
# 0.10709709019314974
# ===========
# 601718.SH
# -0.011156835055228733
# ===========
# 600712.SH
# -0.055415247328062654
# ===========
# 600728.SH
# -0.042112833729877584
# ===========
# 600857.SH
# ===========
# 601166.SH
# -0.12153022314942631
# ===========
# 002198.SZ
# -0.005093180114630769
# ===========
# 300052.SZ
# 0.026624988734519753
# ===========
# 600857.SH
# -0.023470953580339092
# ===========
# 300117.SZ
# ===========
# 601377.SH
# -0.09819346404641124
# ===========
# 300052.SZ
# -0.15309204540108082
# ===========
# 600810.SH
# ===========
# 002711.SZ
# -0.060865762087184444
# -0.118465459324838
# ===========
# 600139.SH
# ===========
# 300117.SZ
# -0.09148926859458388
# ===========
# 600829.SH
# 0.27201105062753694
# ===========
# 600810.SH
# -0.06063444409833813
# ===========
# 000762.SZ
# ===========
# 601377.SH
# 0.01571622715052335
# ===========
# 002336.SZ
# -0.047256995353059786
# ===========
# 000798.SZ
# 0.11690692458410573
# ===========
# 601377.SH
# -0.16392638038638355
# ===========
# 600810.SH
# ===========
# 601258.SH
# -0.047256995353059786
# ===========
# 000798.SZ
# -0.1234325643481414
# ===========
# 300117.SZ
# 0.028959965687679518
